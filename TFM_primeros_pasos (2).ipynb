# %% [markdown]
# # Leemos el archivo .csv

# %%
import pandas as pd
import csv

df = pd.read_csv('Incidents_Responded_to_by_Fire_Companies.csv')
# Out:
# /home/dsc/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (1,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    IM_INCIDENT_KEY FIRE_BOX  \
# 0         63476768     2928
# 1         63476763     1021
# 2         63476761     2745
# 3         63476762     2135
# 4         63476759     1877
#
#                                   INCIDENT_TYPE_DESC      INCIDENT_DATE_TIME  \
# 0   746 - Carbon monoxide detector activation, no CO  06/30/2018 11:55:29 PM
# 1                  300 - Rescue, EMS incident, other  06/30/2018 11:54:44 PM
# 2                   651 - Smoke scare, odor of smoke  06/30/2018 11:54:13 PM
# 3  117 - Commercial Compactor fire, confined to r...  06/30/2018 11:54:08 PM
# 4     710 - Malicious, mischievous false call, other  06/30/2018 11:53:33 PM
#
#         ARRIVAL_DATE_TIME  UNITS_ONSCENE LAST_UNIT_CLEARED_DATE_TIME  \
# 0  07/01/2018 12:00:32 AM            2.0      07/01/2018 12:22:57 AM
# 1  06/30/2018 11:58:59 PM            1.0      07/01/2018 12:09:29 AM
# 2  06/30/2018 11:58:29 PM            3.0      07/01/2018 12:07:50 AM
# 3  06/30/2018 11:58:53 PM            5.0      07/01/2018 12:19:16 AM
# 4  06/30/2018 11:56:50 PM            1.0      06/30/2018 11:57:11 PM
#
#   HIGHEST_LEVEL_DESC  TOTAL_INCIDENT_DURATION  \
# 0   11 - First Alarm                   1648.0
# 1   11 - First Alarm                    885.0
# 2   11 - First Alarm                    817.0
# 3   11 - First Alarm                   1508.0
# 4   11 - First Alarm                    218.0
#
#                                   ACTION_TAKEN1_DESC  ... ZIP_CODE  \
# 0  42 - HazMat detection, monitoring, sampling, &...  ...    10453
# 1                           00 - Action taken, other  ...    11203
# 2                           00 - Action taken, other  ...    10456
# 3      11 - Extinguishment by fire service personnel  ...    10454
# 4                           00 - Action taken, other  ...    11208
#
#    BOROUGH_DESC     FLOOR CO_DETECTOR_PRESENT_DESC  \
# 0     2 - Bronx         1                      Yes
# 1  4 - Brooklyn       NaN                      NaN
# 2     2 - Bronx       NaN                      NaN
# 3     2 - Bronx  basement                      NaN
# 4  4 - Brooklyn       NaN                      NaN
#
#   FIRE_ORIGIN_BELOW_GRADE_FLAG STORY_FIRE_ORIGIN_COUNT FIRE_SPREAD_DESC  \
# 0                          NaN                     NaN              NaN
# 1                          NaN                     NaN              NaN
# 2                          NaN                     NaN              NaN
# 3                          NaN                     NaN              NaN
# 4                          NaN                     NaN              NaN
#
#   DETECTOR_PRESENCE_DESC  AES_PRESENCE_DESC  STANDPIPE_SYS_PRESENT_FLAG
# 0                    NaN                NaN                         NaN
# 1                    NaN                NaN                         NaN
# 2                    NaN                NaN                         NaN
# 3                    NaN                NaN                         NaN
# 4                    NaN                NaN                         NaN
#
# [5 rows x 24 columns]

# %%
df.shape
# Out:
# (2518758, 24)

# %%
df.isnull().sum().sum()
# Out:
# 23920781

# %% [markdown]
# # Leemos el csv Fire Boxes

# %%
df1 = pd.read_csv('Fire_Boxes.csv', header=None)

# %%
df1.head()
# Out:
#           0         1      2                           3
# 0 -73.93253  40.72795  B0014    Gardner Ave & Meeker Ave
# 1 -73.93146  40.72563  B0015    Gardner Ave & Cherry  St
# 2 -73.93622  40.72748  B0018  Bridgewater St & Varick St
# 3 -73.95612  40.72601  B0020    Meserole Ave & Banker St
# 4 -73.95865  40.73626  B0023     Commercial St & Clay St

# %% [markdown]
# # Cambiamos el nombre de las columnas de df1

# %%
df1.columns
# Out:
# Int64Index([0, 1, 2, 3], dtype='int64')

# %%
#cambiamos el tipo a string

df1.columns.astype(str)
# Out:
# Index(['0', '1', '2', '3'], dtype='object')

# %%
#modificamos el nombre de las columnas

df1.columns = ['Long', 'Lat', 'FIRE_BOX', 'Adress']

# %%
df1.columns
# Out:
# Index(['Long', 'Lat', 'FIRE_BOX', 'Adress'], dtype='object')

# %%
df1.head()
# Out:
#        Long       Lat FIRE_BOX                      Adress
# 0 -73.93253  40.72795    B0014    Gardner Ave & Meeker Ave
# 1 -73.93146  40.72563    B0015    Gardner Ave & Cherry  St
# 2 -73.93622  40.72748    B0018  Bridgewater St & Varick St
# 3 -73.95612  40.72601    B0020    Meserole Ave & Banker St
# 4 -73.95865  40.73626    B0023     Commercial St & Clay St

# %%
len(df1["FIRE_BOX"].unique())
# Out:
# 16284

# %%
len(df1["FIRE_BOX"])
# Out:
# 16284

# %% [markdown]
# # Modificamos los dataframe para poder hacer .merge

# %%
#añado ceros en la columna Fire_box del df principal, para que sean números de 4 cifras

df['FIRE_BOX'] = df['FIRE_BOX'].apply(lambda x: '{0:0>4}'.format(x))

# %%
df.head()
# Out:
#    IM_INCIDENT_KEY FIRE_BOX  \
# 0         63476768     2928
# 1         63476763     1021
# 2         63476761     2745
# 3         63476762     2135
# 4         63476759     1877
#
#                                   INCIDENT_TYPE_DESC      INCIDENT_DATE_TIME  \
# 0   746 - Carbon monoxide detector activation, no CO  06/30/2018 11:55:29 PM
# 1                  300 - Rescue, EMS incident, other  06/30/2018 11:54:44 PM
# 2                   651 - Smoke scare, odor of smoke  06/30/2018 11:54:13 PM
# 3  117 - Commercial Compactor fire, confined to r...  06/30/2018 11:54:08 PM
# 4     710 - Malicious, mischievous false call, other  06/30/2018 11:53:33 PM
#
#         ARRIVAL_DATE_TIME  UNITS_ONSCENE LAST_UNIT_CLEARED_DATE_TIME  \
# 0  07/01/2018 12:00:32 AM            2.0      07/01/2018 12:22:57 AM
# 1  06/30/2018 11:58:59 PM            1.0      07/01/2018 12:09:29 AM
# 2  06/30/2018 11:58:29 PM            3.0      07/01/2018 12:07:50 AM
# 3  06/30/2018 11:58:53 PM            5.0      07/01/2018 12:19:16 AM
# 4  06/30/2018 11:56:50 PM            1.0      06/30/2018 11:57:11 PM
#
#   HIGHEST_LEVEL_DESC  TOTAL_INCIDENT_DURATION  \
# 0   11 - First Alarm                   1648.0
# 1   11 - First Alarm                    885.0
# 2   11 - First Alarm                    817.0
# 3   11 - First Alarm                   1508.0
# 4   11 - First Alarm                    218.0
#
#                                   ACTION_TAKEN1_DESC  ... ZIP_CODE  \
# 0  42 - HazMat detection, monitoring, sampling, &...  ...    10453
# 1                           00 - Action taken, other  ...    11203
# 2                           00 - Action taken, other  ...    10456
# 3      11 - Extinguishment by fire service personnel  ...    10454
# 4                           00 - Action taken, other  ...    11208
#
#    BOROUGH_DESC     FLOOR CO_DETECTOR_PRESENT_DESC  \
# 0     2 - Bronx         1                      Yes
# 1  4 - Brooklyn       NaN                      NaN
# 2     2 - Bronx       NaN                      NaN
# 3     2 - Bronx  basement                      NaN
# 4  4 - Brooklyn       NaN                      NaN
#
#   FIRE_ORIGIN_BELOW_GRADE_FLAG STORY_FIRE_ORIGIN_COUNT FIRE_SPREAD_DESC  \
# 0                          NaN                     NaN              NaN
# 1                          NaN                     NaN              NaN
# 2                          NaN                     NaN              NaN
# 3                          NaN                     NaN              NaN
# 4                          NaN                     NaN              NaN
#
#   DETECTOR_PRESENCE_DESC  AES_PRESENCE_DESC  STANDPIPE_SYS_PRESENT_FLAG
# 0                    NaN                NaN                         NaN
# 1                    NaN                NaN                         NaN
# 2                    NaN                NaN                         NaN
# 3                    NaN                NaN                         NaN
# 4                    NaN                NaN                         NaN
#
# [5 rows x 24 columns]

# %%
#funcion para eliminar las letras de la columna Borough_desc

def remove(letter):
    return "".join(x for x in letter if x.isdigit())

# %%
#aplico la funcion remove sobre la columna Borough_desc

df.BOROUGH_DESC = df.BOROUGH_DESC.map(remove) #aplico la funcion remove sobre la columna Borough_desc

# %%
#por si han quedado espacios en blanco, los elimino

df['BOROUGH_DESC'].str.replace(' ','')
# Out:
# 0          2
# 1          4
# 2          2
# 3          2
# 4          4
#           ..
# 2518753    5
# 2518754    5
# 2518755    5
# 2518756    1
# 2518757    2
# Name: BOROUGH_DESC, Length: 2518758, dtype: object

# %%
#cambio los numeros por letras

var_letter = df["BOROUGH_DESC"].astype(str)

df["BOROUGH_DESC"] = var_letter.replace({"1":"M", "2":"X", "3":"R", "4":"B", "5":"Q"}, regex=True)

# %%
df["BOROUGH_DESC"][1]
# Out:
# 'B'

# %%
df.head()
# Out:
#    IM_INCIDENT_KEY FIRE_BOX  \
# 0         63476768     2928
# 1         63476763     1021
# 2         63476761     2745
# 3         63476762     2135
# 4         63476759     1877
#
#                                   INCIDENT_TYPE_DESC      INCIDENT_DATE_TIME  \
# 0   746 - Carbon monoxide detector activation, no CO  06/30/2018 11:55:29 PM
# 1                  300 - Rescue, EMS incident, other  06/30/2018 11:54:44 PM
# 2                   651 - Smoke scare, odor of smoke  06/30/2018 11:54:13 PM
# 3  117 - Commercial Compactor fire, confined to r...  06/30/2018 11:54:08 PM
# 4     710 - Malicious, mischievous false call, other  06/30/2018 11:53:33 PM
#
#         ARRIVAL_DATE_TIME  UNITS_ONSCENE LAST_UNIT_CLEARED_DATE_TIME  \
# 0  07/01/2018 12:00:32 AM            2.0      07/01/2018 12:22:57 AM
# 1  06/30/2018 11:58:59 PM            1.0      07/01/2018 12:09:29 AM
# 2  06/30/2018 11:58:29 PM            3.0      07/01/2018 12:07:50 AM
# 3  06/30/2018 11:58:53 PM            5.0      07/01/2018 12:19:16 AM
# 4  06/30/2018 11:56:50 PM            1.0      06/30/2018 11:57:11 PM
#
#   HIGHEST_LEVEL_DESC  TOTAL_INCIDENT_DURATION  \
# 0   11 - First Alarm                   1648.0
# 1   11 - First Alarm                    885.0
# 2   11 - First Alarm                    817.0
# 3   11 - First Alarm                   1508.0
# 4   11 - First Alarm                    218.0
#
#                                   ACTION_TAKEN1_DESC  ... ZIP_CODE  \
# 0  42 - HazMat detection, monitoring, sampling, &...  ...    10453
# 1                           00 - Action taken, other  ...    11203
# 2                           00 - Action taken, other  ...    10456
# 3      11 - Extinguishment by fire service personnel  ...    10454
# 4                           00 - Action taken, other  ...    11208
#
#   BOROUGH_DESC     FLOOR CO_DETECTOR_PRESENT_DESC  \
# 0            X         1                      Yes
# 1            B       NaN                      NaN
# 2            X       NaN                      NaN
# 3            X  basement                      NaN
# 4            B       NaN                      NaN
#
#   FIRE_ORIGIN_BELOW_GRADE_FLAG STORY_FIRE_ORIGIN_COUNT FIRE_SPREAD_DESC  \
# 0                          NaN                     NaN              NaN
# 1                          NaN                     NaN              NaN
# 2                          NaN                     NaN              NaN
# 3                          NaN                     NaN              NaN
# 4                          NaN                     NaN              NaN
#
#   DETECTOR_PRESENCE_DESC  AES_PRESENCE_DESC  STANDPIPE_SYS_PRESENT_FLAG
# 0                    NaN                NaN                         NaN
# 1                    NaN                NaN                         NaN
# 2                    NaN                NaN                         NaN
# 3                    NaN                NaN                         NaN
# 4                    NaN                NaN                         NaN
#
# [5 rows x 24 columns]

# %%
#uno las dos columnas en una nueva

df['FIRE_BOXX'] = df.apply(lambda row: row['BOROUGH_DESC'] + row['FIRE_BOX'], axis=1)

# %%
df.head()
# Out:
#    IM_INCIDENT_KEY FIRE_BOX  \
# 0         63476768     2928
# 1         63476763     1021
# 2         63476761     2745
# 3         63476762     2135
# 4         63476759     1877
#
#                                   INCIDENT_TYPE_DESC      INCIDENT_DATE_TIME  \
# 0   746 - Carbon monoxide detector activation, no CO  06/30/2018 11:55:29 PM
# 1                  300 - Rescue, EMS incident, other  06/30/2018 11:54:44 PM
# 2                   651 - Smoke scare, odor of smoke  06/30/2018 11:54:13 PM
# 3  117 - Commercial Compactor fire, confined to r...  06/30/2018 11:54:08 PM
# 4     710 - Malicious, mischievous false call, other  06/30/2018 11:53:33 PM
#
#         ARRIVAL_DATE_TIME  UNITS_ONSCENE LAST_UNIT_CLEARED_DATE_TIME  \
# 0  07/01/2018 12:00:32 AM            2.0      07/01/2018 12:22:57 AM
# 1  06/30/2018 11:58:59 PM            1.0      07/01/2018 12:09:29 AM
# 2  06/30/2018 11:58:29 PM            3.0      07/01/2018 12:07:50 AM
# 3  06/30/2018 11:58:53 PM            5.0      07/01/2018 12:19:16 AM
# 4  06/30/2018 11:56:50 PM            1.0      06/30/2018 11:57:11 PM
#
#   HIGHEST_LEVEL_DESC  TOTAL_INCIDENT_DURATION  \
# 0   11 - First Alarm                   1648.0
# 1   11 - First Alarm                    885.0
# 2   11 - First Alarm                    817.0
# 3   11 - First Alarm                   1508.0
# 4   11 - First Alarm                    218.0
#
#                                   ACTION_TAKEN1_DESC  ... BOROUGH_DESC  \
# 0  42 - HazMat detection, monitoring, sampling, &...  ...            X
# 1                           00 - Action taken, other  ...            B
# 2                           00 - Action taken, other  ...            X
# 3      11 - Extinguishment by fire service personnel  ...            X
# 4                           00 - Action taken, other  ...            B
#
#       FLOOR CO_DETECTOR_PRESENT_DESC FIRE_ORIGIN_BELOW_GRADE_FLAG  \
# 0         1                      Yes                          NaN
# 1       NaN                      NaN                          NaN
# 2       NaN                      NaN                          NaN
# 3  basement                      NaN                          NaN
# 4       NaN                      NaN                          NaN
#
#   STORY_FIRE_ORIGIN_COUNT FIRE_SPREAD_DESC DETECTOR_PRESENCE_DESC  \
# 0                     NaN              NaN                    NaN
# 1                     NaN              NaN                    NaN
# 2                     NaN              NaN                    NaN
# 3                     NaN              NaN                    NaN
# 4                     NaN              NaN                    NaN
#
#   AES_PRESENCE_DESC  STANDPIPE_SYS_PRESENT_FLAG  FIRE_BOXX
# 0               NaN                         NaN      X2928
# 1               NaN                         NaN      B1021
# 2               NaN                         NaN      X2745
# 3               NaN                         NaN      X2135
# 4               NaN                         NaN      B1877
#
# [5 rows x 25 columns]

# %%
len(df["FIRE_BOXX"].unique())
# Out:
# 36625

# %%
#modifico el nombre de las columnas del df1

df1.columns = ['Long', 'Lat', 'FIRE_BOXX', 'Adress']

# %%
df1.head()
# Out:
#        Long       Lat FIRE_BOXX                      Adress
# 0 -73.93253  40.72795     B0014    Gardner Ave & Meeker Ave
# 1 -73.93146  40.72563     B0015    Gardner Ave & Cherry  St
# 2 -73.93622  40.72748     B0018  Bridgewater St & Varick St
# 3 -73.95612  40.72601     B0020    Meserole Ave & Banker St
# 4 -73.95865  40.73626     B0023     Commercial St & Clay St

# %% [markdown]
# # Juntamos el df con df1 por la columna FIRE_BOXX

# %%
df2 = pd.merge(df, df1)

# %%
df2.head()
# Out:
#    IM_INCIDENT_KEY FIRE_BOX  \
# 0         63476768     2928
# 1         63332690     2928
# 2         63257739     2928
# 3         63208527     2928
# 4         63187162     2928
#
#                                   INCIDENT_TYPE_DESC      INCIDENT_DATE_TIME  \
# 0   746 - Carbon monoxide detector activation, no CO  06/30/2018 11:55:29 PM
# 1  735A - Unwarranted alarm/defective condition o...  06/02/2018 07:43:40 AM
# 2                  300 - Rescue, EMS incident, other  05/17/2018 02:02:41 PM
# 3                          522 - Water or steam leak  05/07/2018 06:13:26 AM
# 4                  300 - Rescue, EMS incident, other  05/02/2018 07:36:23 PM
#
#         ARRIVAL_DATE_TIME  UNITS_ONSCENE LAST_UNIT_CLEARED_DATE_TIME  \
# 0  07/01/2018 12:00:32 AM            2.0      07/01/2018 12:22:57 AM
# 1  06/02/2018 07:48:48 AM            6.0      06/02/2018 08:11:31 AM
# 2  05/17/2018 02:07:16 PM            1.0      05/17/2018 02:49:41 PM
# 3  05/07/2018 06:19:36 AM            1.0      05/07/2018 06:34:01 AM
# 4  05/02/2018 07:47:00 PM            1.0      05/02/2018 08:17:48 PM
#
#   HIGHEST_LEVEL_DESC  TOTAL_INCIDENT_DURATION  \
# 0   11 - First Alarm                   1648.0
# 1   11 - First Alarm                   1671.0
# 2   11 - First Alarm                   2820.0
# 3   11 - First Alarm                   1235.0
# 4   11 - First Alarm                   2485.0
#
#                                   ACTION_TAKEN1_DESC  ...  \
# 0  42 - HazMat detection, monitoring, sampling, &...  ...
# 1                                   86 - Investigate  ...
# 2                           00 - Action taken, other  ...
# 3                                   86 - Investigate  ...
# 4                           00 - Action taken, other  ...
#
#   FIRE_ORIGIN_BELOW_GRADE_FLAG STORY_FIRE_ORIGIN_COUNT FIRE_SPREAD_DESC  \
# 0                          NaN                     NaN              NaN
# 1                          NaN                     NaN              NaN
# 2                          NaN                     NaN              NaN
# 3                          NaN                     NaN              NaN
# 4                          NaN                     NaN              NaN
#
#   DETECTOR_PRESENCE_DESC AES_PRESENCE_DESC STANDPIPE_SYS_PRESENT_FLAG  \
# 0                    NaN               NaN                        NaN
# 1                    NaN               NaN                        NaN
# 2                    NaN               NaN                        NaN
# 3                    NaN               NaN                        NaN
# 4                    NaN               NaN                        NaN
#
#   FIRE_BOXX       Long        Lat                       Adress
# 0     X2928 -73.922135  40.849047  Undercliff Ave & W 175th St
# 1     X2928 -73.922135  40.849047  Undercliff Ave & W 175th St
# 2     X2928 -73.922135  40.849047  Undercliff Ave & W 175th St
# 3     X2928 -73.922135  40.849047  Undercliff Ave & W 175th St
# 4     X2928 -73.922135  40.849047  Undercliff Ave & W 175th St
#
# [5 rows x 28 columns]

# %%
df2.shape
# Out:
# (2075835, 28)

# %%
df.isnull().sum()
# Out:
# IM_INCIDENT_KEY                       0
# FIRE_BOX                              0
# INCIDENT_TYPE_DESC                    0
# INCIDENT_DATE_TIME                    0
# ARRIVAL_DATE_TIME                 62312
# UNITS_ONSCENE                     62523
# LAST_UNIT_CLEARED_DATE_TIME           2
# HIGHEST_LEVEL_DESC                  152
# TOTAL_INCIDENT_DURATION             149
# ACTION_TAKEN1_DESC                    0
# ACTION_TAKEN2_DESC              1983186
# ACTION_TAKEN3_DESC              2273503
# PROPERTY_USE_DESC                     6
# STREET_HIGHWAY                    38157
# ZIP_CODE                             12
# BOROUGH_DESC                          0
# FLOOR                           1975680
# CO_DETECTOR_PRESENT_DESC        2485756
# FIRE_ORIGIN_BELOW_GRADE_FLAG    2516700
# STORY_FIRE_ORIGIN_COUNT         2504526
# FIRE_SPREAD_DESC                2504527
# DETECTOR_PRESENCE_DESC          2504528
# AES_PRESENCE_DESC               2504528
# STANDPIPE_SYS_PRESENT_FLAG      2504524
# FIRE_BOXX                             0
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# IM_INCIDENT_KEY                       0
# FIRE_BOX                              0
# INCIDENT_TYPE_DESC                    0
# INCIDENT_DATE_TIME                    0
# ARRIVAL_DATE_TIME                 48193
# UNITS_ONSCENE                     48372
# LAST_UNIT_CLEARED_DATE_TIME           2
# HIGHEST_LEVEL_DESC                  125
# TOTAL_INCIDENT_DURATION             127
# ACTION_TAKEN1_DESC                    0
# ACTION_TAKEN2_DESC              1655957
# ACTION_TAKEN3_DESC              1882120
# PROPERTY_USE_DESC                     5
# STREET_HIGHWAY                    30677
# ZIP_CODE                              8
# BOROUGH_DESC                          0
# FLOOR                           1612987
# CO_DETECTOR_PRESENT_DESC        2047909
# FIRE_ORIGIN_BELOW_GRADE_FLAG    2074064
# STORY_FIRE_ORIGIN_COUNT         2063667
# FIRE_SPREAD_DESC                2063668
# DETECTOR_PRESENCE_DESC          2063668
# AES_PRESENCE_DESC               2063668
# STANDPIPE_SYS_PRESENT_FLAG      2063665
# FIRE_BOXX                             0
# Long                                  0
# Lat                                   0
# Adress                                0
# dtype: int64

# %%
df2.isnull().sum().sum()
# Out:
# 19718882

# %%
#df2.reset_index()

# %% [markdown]
# # Eliminamos columnas que no necesitamos

# %%
df2 = df2.drop(['FIRE_ORIGIN_BELOW_GRADE_FLAG', 
               'STORY_FIRE_ORIGIN_COUNT', 
               'FIRE_SPREAD_DESC', 
               'DETECTOR_PRESENCE_DESC', 
               'AES_PRESENCE_DESC', 
               'STANDPIPE_SYS_PRESENT_FLAG', 
               'FLOOR', 
                'ACTION_TAKEN2_DESC', 
                'ACTION_TAKEN3_DESC'], axis=1)

# %%
df2.head()
# Out:
#    IM_INCIDENT_KEY FIRE_BOX  \
# 0         63476768     2928
# 1         63332690     2928
# 2         63257739     2928
# 3         63208527     2928
# 4         63187162     2928
#
#                                   INCIDENT_TYPE_DESC      INCIDENT_DATE_TIME  \
# 0   746 - Carbon monoxide detector activation, no CO  06/30/2018 11:55:29 PM
# 1  735A - Unwarranted alarm/defective condition o...  06/02/2018 07:43:40 AM
# 2                  300 - Rescue, EMS incident, other  05/17/2018 02:02:41 PM
# 3                          522 - Water or steam leak  05/07/2018 06:13:26 AM
# 4                  300 - Rescue, EMS incident, other  05/02/2018 07:36:23 PM
#
#         ARRIVAL_DATE_TIME  UNITS_ONSCENE LAST_UNIT_CLEARED_DATE_TIME  \
# 0  07/01/2018 12:00:32 AM            2.0      07/01/2018 12:22:57 AM
# 1  06/02/2018 07:48:48 AM            6.0      06/02/2018 08:11:31 AM
# 2  05/17/2018 02:07:16 PM            1.0      05/17/2018 02:49:41 PM
# 3  05/07/2018 06:19:36 AM            1.0      05/07/2018 06:34:01 AM
# 4  05/02/2018 07:47:00 PM            1.0      05/02/2018 08:17:48 PM
#
#   HIGHEST_LEVEL_DESC  TOTAL_INCIDENT_DURATION  \
# 0   11 - First Alarm                   1648.0
# 1   11 - First Alarm                   1671.0
# 2   11 - First Alarm                   2820.0
# 3   11 - First Alarm                   1235.0
# 4   11 - First Alarm                   2485.0
#
#                                   ACTION_TAKEN1_DESC  \
# 0  42 - HazMat detection, monitoring, sampling, &...
# 1                                   86 - Investigate
# 2                           00 - Action taken, other
# 3                                   86 - Investigate
# 4                           00 - Action taken, other
#
#             PROPERTY_USE_DESC  STREET_HIGHWAY ZIP_CODE BOROUGH_DESC  \
# 0  429 - Multifamily dwelling  UNDERCLIFF AVE    10453            X
# 1          UUU - Undetermined  UNDERCLIFF AVE    10453            X
# 2          UUU - Undetermined  UNDERCLIFF AVE    10453            X
# 3  429 - Multifamily dwelling  UNDERCLIFF AVE    10453            X
# 4          UUU - Undetermined  UNDERCLIFF AVE    10453            X
#
#   CO_DETECTOR_PRESENT_DESC FIRE_BOXX       Long        Lat  \
# 0                      Yes     X2928 -73.922135  40.849047
# 1                      NaN     X2928 -73.922135  40.849047
# 2                      NaN     X2928 -73.922135  40.849047
# 3                      NaN     X2928 -73.922135  40.849047
# 4                      NaN     X2928 -73.922135  40.849047
#
#                         Adress
# 0  Undercliff Ave & W 175th St
# 1  Undercliff Ave & W 175th St
# 2  Undercliff Ave & W 175th St
# 3  Undercliff Ave & W 175th St
# 4  Undercliff Ave & W 175th St

# %%
df2.shape
# Out:
# (2075835, 19)

# %% [markdown]
# #### Guardamos el csv resultante

# %%
df2.to_csv('df_null.csv', header=True, index=False)

# %% [markdown]
# ## NOTA

# %% [markdown]
# Al realizar el .merge de los dos dataframes, la longitud ha cambiado, de 2.518.758 he pasado a 2.075.835.
# Esto se debe a que el dataset Fire_Boxes no tiene la latitud y longitud de todos los fire box que hay en la ciudad de Nueva York.
# No he conseguido encontrar un dataset que lo tuviera. Por este motivo, he decidido seguir con los datos que han resultado de la combinacion de ambos dataset, ya que es la única manera de poder tener los puntos geográficos.
